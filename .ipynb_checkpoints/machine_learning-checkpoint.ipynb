# %% [markdown]
# # Predicting patient matches from incomplete data
# ### Tony Zhang and David Zhang
#
# * * *
#
# ### 1) Introduction
#
# For this project, we decided to use an algorithm that employed levenshtein's algorithm to detect discrepencies between two patient fields and determine whether the patients are in the same group. With our modified algorithm, we were able to achieve 99.9% accuracy on the test data set, without hardcoding to any specific patients in the given data set. We also considered other algorithms, such as soundex tokens and metaphone, but given the time constraint and the fact that levenshtein was able to accurately predict a large majority of patient matches, we did not implement any additional algorithms and left that for future work.
#
# #### Data Cleaning
#
#
# #### Matching Algorithm
#
#
# #### Accuracy
#
# #### Conclusion
#
# >*asdf
#
# * * *

# %%
import json
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# load patients from csv file
def load_patients(path):
    file = pd.read_csv(path)
    return file

patients = load_patients("./PatientMatchingData.csv")
patients.head()
# Out:
#    GroupID  PatientID Patient Acct # First Name     MI Last Name  \
# 0        1          1    247028705-7     Sutton      J     Power
# 1        1          2            NaN     Suttin  James     Power
# 2        1          3    247028705-7     Sutton      J     Power
# 3        1          4            NaN     Sutton    NaN     Power
# 4        1          5            NaN     SUTTON    NaN     POWER
#
#   Date of Birth   Sex       Current Street 1 Current Street 2  \
# 0     9/20/1945  Male  1858 Sullivan Parkway              NaN
# 1     9/21/1945  Male  1859 Sullivan Parkway               #2
# 2     9/20/1945  Male  1858 Sullivan Parkway              NaN
# 3     9/20/1954  Male  1858 Sullivan Parkway              NaN
# 4     9/20/1954  Male    1858 SULLIVAN PKWAY            APT 2
#
#          ...        Current State Current Zip Code  Previous First Name  \
# 0        ...           California          93726.0                  NaN
# 1        ...           California          93726.0                  NaN
# 2        ...                   CA          93726.0                  NaN
# 3        ...           California          93726.0                  NaN
# 4        ...           California          93726.0                  NaN
#
#   Previous MI Previous Last Name Previous Street 1 Previous Street 2  \
# 0         NaN                NaN   2 Erie Crossing             Apt 9
# 1         NaN                NaN   2 Erie Crossing     Apartment # 9
# 2         NaN                NaN               NaN               NaN
# 3         NaN                NaN               NaN               NaN
# 4         NaN                NaN               NaN               NaN
#
#   Previous City Previous State Previous Zip Code
# 0  Mount Vernon       New York           10557.0
# 1  Mount Vernon       New York           10557.0
# 2           NaN            NaN               NaN
# 3           NaN            NaN               NaN
# 4           NaN            NaN               NaN
#
# [5 rows x 21 columns]

# %%
# Levenshtein Distance Algorithm

def levenshtein(seq1, seq2):
    # if either is null, return 0
    if pd.isna(seq1) or pd.isna(seq2)or seq1 == 'nan' or seq2 == 'nan':
        return 0
    
    size_x = len(seq1) + 1
    size_y = len(seq2) + 1
    matrix = np.zeros ((size_x, size_y))
    for x in range(size_x):
        matrix [x, 0] = x
    for y in range(size_y):
        matrix [0, y] = y

    for x in range(1, size_x):
        for y in range(1, size_y):
            if seq1[x-1] == seq2[y-1]:
                matrix [x,y] = min(
                    matrix[x-1, y] + 1,
                    matrix[x-1, y-1],
                    matrix[x, y-1] + 1
                )
            else:
                matrix [x,y] = min(
                    matrix[x-1,y] + 1,
                    matrix[x-1,y-1] + 1,
                    matrix[x,y-1] + 1
                )
#     print (matrix)
    return (matrix[size_x - 1, size_y - 1])

# %% [markdown]
# Data clean-up

# %%
# show columns and data type for each column
print(patients.columns)
print([type(x) for x in patients.columns])
# Out:
# Index(['GroupID', 'PatientID', 'Patient Acct #', 'First Name', 'MI',
#        'Last Name', 'Date of Birth', 'Sex', 'Current Street 1',
#        'Current Street 2', 'Current City', 'Current State', 'Current Zip Code',
#        'Previous First Name', 'Previous MI', 'Previous Last Name',
#        'Previous Street 1', 'Previous Street 2', 'Previous City',
#        'Previous State', 'Previous Zip Code'],
#       dtype='object')
# [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]

# %%
# treat all columns (besides ID and account #'s) as alphabetic (ie string) for now
alphabeticCols = ['First Name', 'MI',
       'Last Name', 'Date of Birth', 'Sex', 'Current Street 1',
       'Current Street 2', 'Current City', 'Current State', 'Current Zip Code',
       'Previous First Name', 'Previous MI', 'Previous Last Name',
       'Previous Street 1', 'Previous Street 2', 'Previous City',
       'Previous State', 'Previous Zip Code']

patientsClean = patients.copy()


# change everything to lowercase
for col in alphabeticCols:
    patientsClean.loc[:,col] = patientsClean.loc[:,col].astype(str).str.lower()
    
# make gender binary (0 for male 2 for female 1 for unknown)
patientsClean.loc[:,'Sex'] = 0 if patientsClean.loc[:,col][0] == 'M' else 2 if patientsClean.loc[:,col][0] == 'F' else 1
    
    
patientsClean
# Out:
#      GroupID  PatientID Patient Acct # First Name     MI   Last Name  \
# 0          1          1    247028705-7     sutton      j       power
# 1          1          2            NaN     suttin  james       power
# 2          1          3    247028705-7     sutton      j       power
# 3          1          4            NaN     sutton    nan       power
# 4          1          5            NaN     sutton    nan       power
# 5          2          6            NaN     sutton    nan      powers
# 6          2          7            NaN     sutton    nan      powers
# 7          3          8    757393348-7      mikel      l     trayton
# 8          3          9    757393348-7      mikel    lee     trayton
# 9          3         10    757393348-7    michael    nan     trayton
# 10         3         11            NaN       mike    nan     trayton
# 11         3         12    757393348-7      mikel    nan     trayton
# 12         3         13            NaN      mikel      l     trayton
# 13         4         14    930819916-0      dalia    nan        bibb
# 14         4         15            NaN      dalia    nan        bibb
# 15         5         16    887103871-1     myrvyn    nan     buddock
# 16         5         17            NaN     mervin      t     buddock
# 17         5         18            NaN     myrvin    nan     buddock
# 18         5         19            NaN     mervyn    nan     buddock
# 19         6         20            NaN     mervin    nan     buddock
# 20         7         21    146899396-8      cammy    nan    windless
# 21         7         22         CAM123        cam    nan    windless
# 22         7         23            NaN    cameron    nan     windles
# 23         8         24    075148803-8    elenore    nan  macdonnell
# 24         8         25    075148803-8     elenor    nan   mcdonnell
# 25         8         26    075148803-8    elenora    nan    macdonel
# 26         9         27    111421375-6      janet    nan     biasini
# 27         9         28            NaN      janet    nan      bisini
# 28        10         29    303748859-X      darby    nan    steinson
# 29        10         30            NaN     darbie    nan   steiinson
# ..       ...        ...            ...        ...    ...         ...
# 171       53        172    404591211-8      berti    nan      lockie
# 172       53        173            NaN      berti    nan      lockee
# 173       53        174            NaN      berti    nan       locki
# 174       53        175    48521534889      berti    nan      lockie
# 175       54        176    265234041-7      zarah    nan        dake
# 176       54        177            NaN      sarah    nan        dake
# 177       54        178    265234041-7       sara    nan       drake
# 178       55        179    361284643-4    madison   gena       pybus
# 179       55        180            NaN     maddie      g       pybus
# 180       55        181    584121154-1    madison    nan           p
# 181       55        182            NaN    madison    nan      piebus
# 182       56        183      488721348    madison      q       pybus
# 183       57        184    101138829-4      early    nan    burnyeat
# 189    12/15/1970    1               1619 78th roed              nan
# 190      5/5/1986    1       12405 teiter heights e              nan
# 191      5/5/1986    1       12405 teiter heights e              nan
# 192      5/5/1986    1       12405 teiter heights e              nan
# 193      5/5/1986    1       12405 teiter heights e              nan
# 194     12/1/2015    1           15424 jeffies lane            apt 2
# 195     12/1/2015    1           15424 jeffies lane            apt 2
# 196     5/16/1972    1         16595 city view lane              nan
# 197     5/16/1972    1                          nan              nan
# 198     3/17/2010    1              9850 kelso road              nan
# 199     3/17/2010    1                          nan              nan
# 200     3/17/2010    1                          nan              nan
#
#            ...          Current State Current Zip Code Previous First Name  \
# 0          ...             california          93726.0                 nan
# 1          ...             california          93726.0                 nan
# 2          ...                     ca          93726.0                 nan
# 3          ...             california          93726.0                 nan
# 4          ...             california          93726.0                 nan
# 5          ...             california          93726.0              sutton
# 6          ...             california          93726.0                 nan
# 7          ...                arizona          85219.0                 nan
# 8          ...                arizona          85219.0                 nan
# 9          ...                     az          85219.0                 nan
# 10         ...                arizona          85219.0                 nan
# 11         ...                arizona          85219.0                 nan
# 12         ...                     az          85219.0                 nan
# 13         ...                     ny          11447.0                 nan
# 14         ...               new york          11447.0                 nan
# 15         ...             california          92812.0                 nan
# 16         ...                     ca          92812.0                 nan
# 17         ...             california          92812.0                 nan
# 18         ...             california          92812.0                 nan
# 19         ...             california          92812.0                 nan
# 20         ...             california          93709.0                 nan
# 21         ...                     ca          93709.0                 cam
# 22         ...             california          93709.0                 nan
# 23         ...                georgia          31106.0                 nan
# 24         ...                     ga          31106.0              elenor
# 25         ...                georgia          31106.0                 nan
# 26         ...         north carolina          27615.0                 nan
# 27         ...         north carolina          27615.0               janet
# 28         ...                  texas          77035.0                 nan
# 29         ...                  texas          77035.0                 nan
# ..         ...                    ...              ...                 ...
# 171        ...               virginia          22234.0                 nan
# 172        ...                     va              nan                 nan
# 173        ...               virginia          22234.0                 nan
# 174        ...                     va          22234.0                 nan
# 175        ...             california          95219.0             michael
# 176        ...                    nan          95219.0                 nan
# 177        ...             california              nan                 nan
# 178        ...                 oregon          97211.0                 nan
# 179        ...                     or           9721.0                 nan
# 180        ...                     pr              nan                 nan
# 181        ...                 oregon          97211.0                 nan
# 182        ...                     wa          98683.0                 nan
# 183        ...                     pa          16107.0                 nan
# 184        ...                     pa          16107.0                 nan
# 185        ...                     pa           1610.0                 nan
# 186        ...                     wa          98683.0                 nan
# 187        ...                     wa          98683.0                 nan
# 188        ...                     wa          98683.0                 nan
# 189        ...                     wa          98683.0                 nan
# 190        ...                     wa          98626.0                 nan
# 191        ...                     wa          98626.0                 nan
# 192        ...                     wa          98626.0                 nan
# 193        ...                     wa          98626.0                 nan
# 194        ...                     wa          98683.0                 nan
# 195        ...                     wa          98683.0                 nan
# 196        ...                     wa          98684.0                 nan
# 197        ...                    nan              nan                 nan
# 198        ...                     wa          98626.0                 nan
# 199        ...                    nan              nan                 nan
# 200        ...                    nan              nan                 nan
#
#     Previous MI Previous Last Name          Previous Street 1  \
# 0           nan                nan            2 erie crossing
# 1           nan                nan            2 erie crossing
# 2           nan                nan                        nan
# 3           nan                nan                        nan
# 4           nan                nan                        nan
# 5           nan               lore                        nan
# 6           nan                nan                        nan
# 178               615    sioux city           iowa           51110.0
# 179               nan    sioux city             ia           51110.0
# 180               nan           nan           iowa               nan
# 181               615    sioux city           iowa           51110.0
# 182               nan           nan            nan               nan
# 183               nan           nan            nan               nan
# 184               nan           nan            nan               nan
# 185               nan           nan            nan               nan
# 186               nan           nan            nan               nan
# 187               nan           nan            nan               nan
# 188               nan           nan            nan               nan
# 189               nan           nan            nan               nan
# 190               nan           nan            nan               nan
# 191               nan           nan            nan               nan
# 192               nan           nan            nan               nan
# 193               nan           nan            nan               nan
# 194               nan           nan            nan               nan
# 195               nan           nan            nan               nan
# 196               nan           nan            nan               nan
# 197               nan           nan            nan               nan
# 198               nan           nan            nan               nan
# 199               nan           nan            nan               nan
# 200               nan           nan            nan               nan
#
# [201 rows x 21 columns]

# %%
# verify if patient1 and patient2 are the same person
# need to determine optimal cutoffs (ie what levenshtein score is considered "different" enough to be 2 different people?)
def verify(patient1, patient2):
    numErrors = 0 # error considered as a field that is significantly different
    # consider first name
    if levenshtein(patient1['First Name'], patient2['First Name']) > 2:
        numErrors += 1
    # consider middle name
    if patient1['MI'] != 'nan' and patient2['MI'] != 'nan':
        if patient1['MI'][0] != patient2['MI'][0]:
            numErrors += 1
    # consider last name
    if levenshtein(patient1['Last Name'], patient2['Last Name']) > 2:
        numErrors += 1
    # consider DOB - more strict evaluation b/c less likely to mistype date of birth > 3 typos
    if levenshtein(patient1['Date of Birth'], patient2['Date of Birth']) > 3:
        # make sure there aren't any swapped character typos
        # TODO: swapped regex ?
        return False
    elif levenshtein(patient1['Date of Birth'], patient2['Date of Birth']) > 2:
        numErrors += 1
    # consider gender
    if patient1['Sex'] != patient2['Sex']:
        numErrors += 1
    # consider current street 1
    if levenshtein(patient1['Current Street 1'], patient2['Current Street 1']) > 2:
        numErrors += 1
    # consider current city
    if levenshtein(patient1['Current City'], patient2['Current City']) > 2:
        numErrors += 1
    # consider zip
    if levenshtein(patient1['Current Zip Code'], patient2['Current Zip Code']) > 2:
            numErrors += 1
    return numErrors <= 1

# %%
# Evaluation function to test accuracy
total = 0
correct = 0
falsePos = 0
falseNeg = 0
for index, patient in patientsClean.iterrows():
    for index1, patient1 in patientsClean.iterrows():
        if(index1 > index):
            result = verify(patient, patient1)
            ID1 = patient['GroupID']
            ID2 = patient1['GroupID']
            if result == True and ID1 == ID2 or result == False and ID1 != ID2:
                correct += 1
            elif result == True and ID1 != ID2:
#                 print('false positive found between patients: ', patient, " and ", patient1)
                falsePos += 1
            elif result == False and ID1 == ID2:
#                 print('false negative found between patients: ', patient['PatientID'], " and ", patient1['PatientID'])
                falseNeg += 1
            total += 1

print("correct: ", correct)
print("total: ", total)
print("false positives: ", falsePos)
print("false negatives: ", falseNeg)
print("accuracy: ", correct/total)
# Out:
# correct:  20078
# total:  20100
# false positives:  10
# false negatives:  12
# accuracy:  0.998905472636816

# %%
# Data to plot
labels =["Correct","Incorrect"]
sizes = [correct, total-correct]
colors = ["lightblue","whitesmoke"]
explode = (0.1,0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140,)
plt.axis('equal')
plt.show()

# %%
# Data to plot
labels =["False Positives","False Negatives"]
sizes = [falsePos, falseNeg]
colors = ["lightblue","whitesmoke"]
explode = (0.1,0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140,)
plt.axis('equal')
plt.show()
